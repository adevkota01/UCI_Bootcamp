# %%
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func
import pandas as pd

import matplotlib
from matplotlib import style
style.use('seaborn')
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
import psycopg2
engine = "host='localhost' dbname='employee_db' user='postgres' password='postgres'"
connection = psycopg2.connect(engine)

# %%
engine = create_engine('postgresql+psycopg2://postgres:postgres@localhost/employee_db')

# %%
results = engine.execute("SELECT * FROM salaries").fetchall()

# %%
Base = automap_base()
Base.prepare(engine, reflect=True)
Salaries = Base.classes.salaries

# %%
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['employees', 'dept_emp', 'departments', 'dept_manager', 'salaries', 'titles']

# %%
session = Session(engine)

# %%
columns = inspector.get_columns('salaries')
for c in columns:
    print(c['name'], c["type"])
# Out:
# emp_no INTEGER
# salary INTEGER
# from_date DATE
# to_date DATE

# %%
salaries = [int(result[1]) for result in results]
salaries
# Out:
# [60117,
#  65828,
#  40006,
#  40054,
#  78228,
#  40000,
#  56724,
#  46671,
#  60929,
#  72488,
#  42365,
#  40000,
#  40000,
#  46168,
#  40000,
#  70889,
#  71380,
#  55881,
#  44276,
#  40000,
#  55025,
#  40000,
#  47883,
#  83733,
#  40000,
#  47585,
#  40000,
#  48859,
#  63163,
#  66956,
#  40000,
#  48426,
#  51258,
#  47561,
#  41538,
#  42819,
#  40000,
#  40000,
#  40000,
#  52153,
#  56893,
#  81662,
#  49324,
#  40919,
#  41971,
#  40000,
#  54982,
#  40000,
#  40000,
#  74366,
#  48817,
#  57212,
#  67854,
#  40000,
#  80024,
#  48857,
#  49616,
#  52787,
#  71218,
#  74686,
#  68577,
#  55685,
#  40000,
#  40000,
#  40000,
#  69736,
#  44642,
#  87964,
#  67932,
#  55999,
#  40000,
#  40000,
#  56473,
#  61714,
#  43815,
#  47319,
#  40000,
#  47280,
#  53492,
#  54916,
#  55786,
#  48935,
#  40000,
#  69811,
#  40000,
#  81613,
#  96750,
#  65957,
#  56469,
#  44978,
#  40000,
#  53977,
#  67856,
#  58001,
#  63668,
#  61395,
#  44886,
#  40000,
#  68781,
#  54398,
# ...

# %%
           

plt.hist(salaries, bins = 20)
plt.title('Salaries of employees')
plt.xlabel('Salaries')
plt.ylabel('Counts')

plt.show()
